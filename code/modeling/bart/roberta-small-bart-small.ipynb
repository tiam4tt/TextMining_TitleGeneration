# %%
# Install dependencies
# !pip install transformers torch pandas keybert scikit-learn tqdm rouge_score bert_score
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Collecting keybert
#   Downloading keybert-0.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.11/dist-packages (from keybert) (14.0.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from keybert) (3.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert_score) (3.7.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.4.0->keybert) (2.19.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.3.8->keybert) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert_score) (3.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.2 MB/s eta 0:00:00
# Downloading keybert-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.9 MB/s eta 0:00:00
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.7 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=1d64048e0ae4fd3f92e69b9fbabc35bfb6b3140b1f274a2e8d418978c29a8b6d
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, rouge_score, keybert, bert_score
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed bert_score-0.3.13 keybert-0.9.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rouge_score-0.1.2

# %%
import pandas as pd
import torch
import torch.nn as nn
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from keybert import KeyBERT
from sklearn.preprocessing import MultiLabelBinarizer
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from tqdm import tqdm
import numpy as np
import os

# Preprocess dataset to extract title keywords
def preprocess_dataset(input_csv, output_csv):
    df = pd.read_csv(input_csv)
    kw_model = KeyBERT()
    
    def extract_keywords(title):
        try:
            keywords = kw_model.extract_keywords(
                title, keyphrase_ngram_range=(1, 7), top_n=10
            )
            return ' '.join([kw[0] for kw in keywords])
        except:
            return ''
    
    df['title_keywords'] = df['title'].apply(extract_keywords)
    df.to_csv(output_csv, index=False)
    return df

# Custom Dataset for RoBERTa
class KeywordDataset(Dataset):
    def __init__(self, csv_file, tokenizer, mlb, max_length=512):
        self.df = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.mlb = mlb
        self.max_length = max_length

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        abstract = str(self.df.iloc[idx]['abstract'])
        keywords = str(self.df.iloc[idx]['title_keywords']).split()

        encoding = self.tokenizer(
            abstract,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        labels = self.mlb.transform([keywords])[0]
        labels = torch.tensor(labels, dtype=torch.float32)

        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze(),
            'labels': labels
        }

# Training Function
def train_roberta(model, train_loader, val_loader, device, epochs=3, lr=2e-5):
    optimizer = AdamW(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for batch in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            loss = criterion(outputs.logits, labels)
            total_train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_train_loss = total_train_loss / len(train_loader)
        print(f"Epoch {epoch + 1}, Average Training Loss: {avg_train_loss:.4f}")

        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f"Validation Epoch {epoch + 1}"):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                outputs = model(input_ids, attention_mask=attention_mask)
                loss = criterion(outputs.logits, labels)
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        print(f"Epoch {epoch + 1}, Average Validation Loss: {avg_val_loss:.4f}")

# Main Execution
if __name__ == "__main__":
    # File paths
    train_csv = '/kaggle/input/springerjournal-450tk-0-7cosine/train.csv'
    val_csv = '/kaggle/input/springerjournal-450tk-0-7cosine/val.csv'
    processed_train_csv = '/kaggle/working/processed_train.csv'
    processed_val_csv = '/kaggle/working/processed_val.csv'

    # Preprocess datasets
    preprocess_dataset(train_csv, processed_train_csv)
    preprocess_dataset(val_csv, processed_val_csv)

    # Initialize device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load keyword vocabulary
    train_data = pd.read_csv(processed_train_csv)
    train_keywords = train_data['title_keywords'].apply(lambda x: x.split() if x else []).values
    # Limit vocabulary size to avoid memory issues
    keyword_counts = {}
    for sublist in train_keywords:
        for kw in sublist:
            keyword_counts[kw] = keyword_counts.get(kw, 0) + 1
    top_keywords = sorted(keyword_counts.items(), key=lambda x: x[1], reverse=True)[:1000]
    keyword_vocab = [kw for kw, _ in top_keywords]
    mlb = MultiLabelBinarizer(classes=keyword_vocab)
    # Fit the MultiLabelBinarizer with training keywords
    mlb.fit(train_keywords)

    # Initialize tokenizer and datasets
    tokenizer = AutoTokenizer.from_pretrained('roberta-base')
    train_dataset = KeywordDataset(processed_train_csv, tokenizer, mlb)
    val_dataset = KeywordDataset(processed_val_csv, tokenizer, mlb)

    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

    # Initialize RoBERTa model
    model = AutoModelForSequenceClassification.from_pretrained(
        'roberta-base',
        num_labels=len(keyword_vocab),
        problem_type='multi_label_classification'
    ).to(device)

    # Train RoBERTa
    train_roberta(model, train_loader, val_loader, device, epochs=3, lr=2e-5)

    # Save the model
    os.makedirs('/kaggle/working/finetuned_roberta_keywords', exist_ok=True)
    model.save_pretrained('/kaggle/working/finetuned_roberta_keywords')
    tokenizer.save_pretrained('/kaggle/working/finetuned_roberta_keywords')
    # Save keyword vocabulary
    with open('/kaggle/working/keyword_vocab.txt', 'w') as f:
        f.write('\n'.join(keyword_vocab))
# Out:
# 2025-05-15 14:55:41.024331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747320941.208792      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747320941.258302      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training Epoch 1:   0%|          | 0/223 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['beta', 'sliding'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['converter', 'densenet', 'el', 'flame', 'steelmaking'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['medicine', 'radiomics', 'thyroid'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['vortex'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['blurred'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['jets', 'nozzle', 'quiescent'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['aquaculture', 'behavioral', 'phenotype', 'stereo'] will be ignored
#   warnings.warn(
# Training Epoch 1:   0%|          | 1/223 [00:00<03:11,  1.16it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['contracts', 'dl4sc'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['objects', 'step'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['logging'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['birdnet', 'coyotes', 'identify', 'potentially', 'wolves'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['apt'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['gap', 'intentionality', 'preter'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['agglomeration', 'regional'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['euro', 'inflation'] will be ignored
#   warnings.warn(
# Training Epoch 1:   1%|          | 2/223 [00:01<01:38,  2.25it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cuproptosis', 'fdx1', 'gene', 'identified', 'ovarian'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['approximation', 'brownian', 'deformed', 'parametrized'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['aircraft', 'deepat'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['general'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['compilers', 'tvm'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['smarttracing'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['policy'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['decoherence'] will be ignored
#   warnings.warn(
# Training Epoch 1:   1%|▏         | 3/223 [00:01<01:51,  1.98it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['conditions', 'distillation', 'working'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['direction'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['subset'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['dpd'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['antenna', 'bio', 'fractal', 'gasket', 'sierpinski'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['sgamte'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['radiographs', 'skeletal'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['aid', 'better', 'ni', 'oxidation'] will be ignored
#   warnings.warn(
# Training Epoch 1:   2%|▏         | 4/223 [00:02<01:56,  1.87it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['rayleigh', 'responses', 'scattering'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['automatically', 'similar'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['al7075'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['satisfaction'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['peptide', 'transdermal'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['absence'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cyber', 'logs'] will be ignored
#   warnings.warn(
# Training Epoch 1:   2%|▏         | 5/223 [00:02<02:00,  1.82it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['bonds', 'disulphide', 'potent'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['total'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['semg', 'wearable'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['dancer', 'electronics', 'multispan', 'printed', 'regulation', 'tension'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['derived', 'khalimsky', 'topological'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['abrm'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['nondestructive', 'pi', 'raspberry', 'yolk'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['coreference', 'mention'] will be ignored
#   warnings.warn(
# Training Epoch 1:   3%|▎         | 6/223 [00:03<02:01,  1.79it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['heart', 'proteins', 'secreted'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['focus', 'regeneration', 'scaffolds', 'vascular'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ada', 'esrgan', 'font', 'stylegan2', 'thai'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['convnext', 'dermoscopy'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['attribute', 'dependency'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['paint'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['clipping', 'discussion', 'page', 'topics'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['devaluation', 'reduced', 'sensitivity', 'substance'] will be ignored
#   warnings.warn(
# Training Epoch 1:   3%|▎         | 7/223 [00:03<02:01,  1.77it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['iteration', 'policy'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lcp', 'mixer', 'nlp', 'perception'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['archaeobotanical', 'microct'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['makespan', 'shop'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['clouds', 'volcanic'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['exposure', 'mexican', 'origin', 'pro', 'smoking', 'youth'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['bursty'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['following', 'leader'] will be ignored
#   warnings.warn(
# Training Epoch 1:   4%|▎         | 8/223 [00:04<02:02,  1.76it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['spotting'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['advances', 'dialog'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['dfp', 'quantized', 'shifted'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['macrosegregation'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['desulfurization', 'fcm', 'lssvm', 'pls'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['beams', 'flexural', 'rods'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['memristive'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['analytical', 'center'] will be ignored
#   warnings.warn(
# Training Epoch 1:   4%|▍         | 9/223 [00:05<02:02,  1.75it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['detectors', 'robustness'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['marking'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['1d', 'isomap', 'representations'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['preserved', 'sapda', 'significant'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['particleboard', 'resin'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lung', 'segmented', 'vessel'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['abnormal', 'bases'] will be ignored
#   warnings.warn(
# Training Epoch 1:   4%|▍         | 10/223 [00:05<02:01,  1.75it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['adjusting', 'spine'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['histopathological'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ctu', 'frame', 'perceptual'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['calligraphy', 'carved', 'characters', 'stone'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['infection'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['deduplication', 'storage'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['eganet', 'elevation', 'panchromatic'] will be ignored
#   warnings.warn(
# Training Epoch 1:   5%|▍         | 11/223 [00:06<02:01,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['linex'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['hrv', 'patients', 'tachyarrhythmia', 'ventricular', 'vlf'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ecg', 'measure', 'transferability'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['classifiers', 'differentially', 'fairness', 'margin'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['biological', 'composition', 'compounds', 'functional', 'metabolic', 'pathways'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['algal', 'chlorophylla', 'secchi', 'turbidity'] will be ignored
#   warnings.warn(
# Training Epoch 1:   5%|▌         | 12/223 [00:06<02:01,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['library', 'secretary'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['logic', 'remolded', 'shear', 'undrained'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['exploitation', 'optimizing', 'tradeoff'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['adaboost', 'paired'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['material', 'multisensor'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cascading', 'deepcascade', 'results', 'weak', 'wr'] will be ignored
#   warnings.warn(
# Training Epoch 1:   6%|▌         | 13/223 [00:07<02:00,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['encoder'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ctc', 'pho', 'sc', 'zero'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['functional', 'peptide', 'sc', 'therapeutic', 'tppred'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['contact', 'irregularities', 'pantograph'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['project'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['convsnp', 'like', 'neurons', 'snp'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['armed', 'bangladesh', 'conflict'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['beta', 'hill', 'optimizer'] will be ignored
#   warnings.warn(
# Training Epoch 1:   6%|▋         | 14/223 [00:07<02:00,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['decoder', 'encoder'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['assignment', 'ucav'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['clda'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['constraint', 'relative'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['asmnet', 'fiducial', 'jordan'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['blastability', 'mass', 'tendency'] will be ignored
#   warnings.warn(
# Training Epoch 1:   7%|▋         | 15/223 [00:08<01:59,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['telemedicine'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['fam', 'focal'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['databases'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['edvam', 'eye', 'museum'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lstmp', 'tdnn'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['coating', 'sherardizing'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['bounds', 'erm', 'generalization', 'samples'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['named'] will be ignored
#   warnings.warn(
# Training Epoch 1:   7%|▋         | 16/223 [00:09<01:59,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['bike'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['academic', 'college', 'connectedness', 'motivation', 'retention', 'year'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['contextual', 'ftcn'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['henon'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['nsct', 'pcnn', 'qiga'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ic', 'partitioning', 'placement', 'tsv'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['flux', 'mold', 'viscosity'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['binarization', 'multiclass', 'neuroevolution'] will be ignored
#   warnings.warn(
# Training Epoch 1:   8%|▊         | 17/223 [00:09<01:58,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['arabia', 'gddi', 'kingdom', 'saudi', 'storm'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['braking', 'ggap', 'ghmm'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['springback', 'stretch'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['slic'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['archetypes'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['modelling'] will be ignored
#   warnings.warn(
# Training Epoch 1:   8%|▊         | 18/223 [00:10<01:58,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['filling', 'interaction'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['isolation', 'switch', 'traction'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['correlations', 'jointed', 'weakly'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['crash', 'photo'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['iliou', 'preprocessing'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['2l', 'mf', 'predpromoter', 'promoter'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['elliptical', 'heavy', 'tungsten'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['aviation'] will be ignored
#   warnings.warn(
# Training Epoch 1:   9%|▊         | 19/223 [00:10<01:57,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['backplane'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cdn', 'icps'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['extended'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['idh', 'mutation', 'radiomics'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['inflow'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['better', 'keytitle', 'keywords', 'title'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['avoidance', 'obstacle'] will be ignored
#   warnings.warn(
# Training Epoch 1:   9%|▉         | 20/223 [00:11<01:57,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['appliance', 'consumption', 'customers', 'meter', 'peak', 'residential'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['drill', 'emergency', 'paraviewweb', 'vr'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['bifurcation', 'burst', 'fhn', 'hopf', 'simplified'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['refusion', 'splitting', 'stranslot'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['dys', 'miner', 'yolov8n'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lie'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['fin', 'rudder', 'stabilization'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['characterisation', 'dumps', 'spoil'] will be ignored
#   warnings.warn(
# Training Epoch 1:   9%|▉         | 21/223 [00:11<01:56,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['hopfield', 'multivalued', 'salesman', 'traveling'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['diesel', 'signals'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['kinect', 'stereo'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['plan'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['acquisition', 'position', 'seam'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['impurities', 'peppers'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['imbalance'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['rc'] will be ignored
#   warnings.warn(
# Training Epoch 1:  10%|▉         | 22/223 [00:12<01:55,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['extension', 'opencl', 'pytorch'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['specialty'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['advance', 'cylindrical', 'finishing', 'rollers'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['elman', 'exhalation', 'radon', 'vmd'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['architectures', 'fcos', 'nas'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['administration', 'analyzing', 'assessments', 'computerized', 'decisions', 'formative', 'optimize'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['dropout', 'gene', 'scrna', 'seq'] will be ignored
#   warnings.warn(
# Training Epoch 1:  10%|█         | 23/223 [00:13<01:55,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cosine', 'pi', 'sigma', 'sine'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['physical', 'things'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ching', 'operators', 'shadowed'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['artifacts', 'relative', 'removing', 'total', 'unidirectional', 'variation'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['designed', 'experimental', 'nanosheets', 'producing'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['arch', 'bridges', 'mobilevit'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['database', 'ml', 'predicates', 'sql'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['distress'] will be ignored
#   warnings.warn(
# Training Epoch 1:  11%|█         | 24/223 [00:13<01:54,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['province', 'sichuan'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['airborne', 'patrolling'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['rf'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ho', 'polarised', 'purity', 'radially', 'transverse', 'yag'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['awareness', 'tnet'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['2010', '2019', 'hydro', 'ict', 'scientometric'] will be ignored
#   warnings.warn(
# Training Epoch 1:  11%|█         | 25/223 [00:14<01:54,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cultivated', 'pixel', 'rape'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['including', 'seat', 'suspended', 'tractor', 'wheeled'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['gaze', 'help', 'infused', 'signals'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['roberta'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['powered'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['annotation', 'ant'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['awareness', 'poi', 'queuing'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['farmland', 'mortgage', 'pricing', 'right'] will be ignored
#   warnings.warn(
# Training Epoch 1:  12%|█▏        | 26/223 [00:14<01:53,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['effectiveness', 'enterprises', 'governance'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['sac', 'track'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['disparity', 'ssnet'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['element', 'springback'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lmsvcr'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['conditions', 'optimality', 'tucker'] will be ignored
#   warnings.warn(
# Training Epoch 1:  12%|█▏        | 27/223 [00:15<01:53,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['prioritized'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['mineral', 'prospectivity'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['closure', 'loop'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['flaw'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['critical', 'mid', 'snowmelt'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['copula', 'ihacres'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['posture', 'swimming'] will be ignored
#   warnings.warn(
# Training Epoch 1:  13%|█▎        | 28/223 [00:16<01:52,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['counterfeit', 'handbag', 'logo', 'luxury'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['license'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['elastic', 'mini', 'modulus', 'tensile'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['discontinuity', 'ocm'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['annular', 'bolted', 'joints', 'material', 'radially', 'segmented'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['pterygium'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['caption', 'vmsg'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['traditional'] will be ignored
#   warnings.warn(
# Training Epoch 1:  13%|█▎        | 29/223 [00:16<01:51,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lbp', 'octagonal', 'prism'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['banana', 'indicator', 'ripening', 'stages'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['adverse', 'gridformer', 'weather'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['setting', 'tension', 'titanium'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['degenerative', 'lumbar', 'spine', 'utility'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['diesel', 'gwo', 'nox'] will be ignored
#   warnings.warn(
# Training Epoch 1:  13%|█▎        | 30/223 [00:17<01:51,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['focused', 'planogram'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['metrics'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['attractors', 'sprott'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['authentication', 'fedfv'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['disaster'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['dos'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['designing', 'investigation', 'noticing', 'practical', 'practices', 'preferences', 'qualitative', 'work'] will be ignored
#   warnings.warn(
# Training Epoch 1:  14%|█▍        | 31/223 [00:17<01:50,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['condition', 'modelling'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['flight', 'octorotor', 'tuning'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['mood', 'songs', 'western'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['polymorphic', 'torus'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['coevolutionary'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['homogenate', 'lc', 'nicotinate', 'octyl'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['automode', 'swarms'] will be ignored
#   warnings.warn(
# Training Epoch 1:  14%|█▍        | 32/223 [00:18<01:50,  1.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['discourse', 'parsing'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['implementation', 'panel'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['densely', 'mosaic', 'occluded'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['anfis'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['country', 'differences', 'financing', 'rounds'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['confocal', 'probes'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['descriptors'] will be ignored
#   warnings.warn(
# Training Epoch 1:  15%|█▍        | 33/223 [00:18<01:49,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['preload'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['canny', 'classical', 'detector', 'implementation'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ant', 'colony', 'things'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['course', 'gamified', 'motivation'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['paid'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['robots'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ribosome', 'stalling'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['quran', 'recitation', 'trends'] will be ignored
#   warnings.warn(
# Training Epoch 1:  15%|█▌        | 34/223 [00:19<01:48,  1.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['disorder', 'resdense', 'schizophrenia'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['aloud', 'assisted', 'think', 'transcripts'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cartoon', 'dog', 'parsing', 'pyramid'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['propagation'] will be ignored
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['abstractive', 'extractive'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['attributes', 'itabnet', 'socioeconomic', 'tabular'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['input'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['arthroplasty', 'knee', 'operative', 'primary', 'surgical', 'total'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['feunet', 'shaped'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['article', 'crop', 'database', 'grower', 'indoor', 'retracted'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['duality', 'simulations'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  64%|██████▍   | 18/28 [00:02<00:01,  7.72it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['conditions', 'dissemination', 'employment', 'lap', 'population', 'sap', 'sustainable'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['indices', 'salinity'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['binning', 'contigs', 'databases', 'metagenomic'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['crowded'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['chromosomes', 'designer', 'difficulties'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['emotional', 'engagement', 'gaming', 'happiness', 'life', 'motives', 'pandemic', 'primary', 'traits'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cqcnn', 'sv', 'wideband'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['loitering'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  68%|██████▊   | 19/28 [00:02<00:01,  7.72it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['fracture', 'mask', 'pit', 'slope'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['histopathology', 'matnet', 'nuclei', 'thymoma'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['macsa'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['clothing', 'thresholding', 'triclass'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['black', 'option', 'pricing', 'scholes'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['localisation', 'overhead', 'topological'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['movie', 'office', 'revenues'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['minimal', 'mlm'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  71%|███████▏  | 20/28 [00:02<00:01,  7.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['collaborative', 'transport'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lexicon', 'pronunciation', 'syntax'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['developing', 'intermodal', 'mobility', 'typology', 'unimodal'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['fedci', 'fedclus', 'validity'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['marathi'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['article', 'faces', 'tiny'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  75%|███████▌  | 21/28 [00:03<00:00,  7.75it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['black', 'dcgan', 'poisoning', 'poisonous'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['clergy', 'finland', 'lutheran', 'orientation', 'profiles', 'wellbeing', 'work'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['padding'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['eye', 'movement', 'proficiency'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['coding', 'cost', 'devices', 'hevc', 'intra', 'screen', 'sensitive'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['sroc'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['ann', 'gas', 'multicomponent'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['built', 'mobility', 'ridership', 'taxi'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  79%|███████▊  | 22/28 [00:03<00:00,  7.75it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['behavioural', 'botnets', 'exploring'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['android', 'intents', 'ipanalyzer', 'permissions', 'ranked'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['parameter', 'rvfl'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['return'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['glove', 'implementation', 'wearable'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['current', 'eddy', 'titanium'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['drying', 'far', 'ginger', 'logic', 'slices'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['raster'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  82%|████████▏ | 23/28 [00:03<00:00,  7.72it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['elman', 'pls', 'reliable', 'sample'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['candidates', 'empathy', 'medicine', 'motivational', 'school', 'studying'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['molten', 'tundish'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['stereo', 'vovnet'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['coupling', 'ecg', 'personal'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['apply', 'argument', 'does', 'miracles'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['chess'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['creation', 'database', 'folk', 'mizo', 'preliminary', 'songs'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  86%|████████▌ | 24/28 [00:03<00:00,  7.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['guzheng', 'pedagogy'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['classifiers', 'permutation'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['formulation', 'material', 'plugging'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['clouds', 'hough'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['annoyance', 'brake', 'classes', 'creep', 'different', 'groan', 'psychoacoustic', 'subjective'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['adverse', 'reactions', 'xinjiang'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['alpha', 'conditions', 'different', 'portfolio', 'tail'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['desert', 'horizon', 'occurrence', 'petrogypsic', 'sahara'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  89%|████████▉ | 25/28 [00:03<00:00,  7.75it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['context', 'duration', 'emotional', 'overview', 'phone'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['lexicon', 'phrase'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['applicability', 'coefficient', 'pythagorean'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['coefficient', 'picture'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['annotation', 'keyword'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['safe'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['controller', 'evolutionary', 'quadruple', 'tank'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['reviews'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  93%|█████████▎| 26/28 [00:03<00:00,  7.76it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['classifying', 'cognates', 'extracting', 'false', 'friends', 'pairs'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['deepn4', 'n4itk', 't1'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['biomass', 'storage'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['brightness', 'sbc'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['encoded', 'smile'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['affinity', 'candidates', 'smiles2dta'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['incorporating', 'partition', 'picture', 'possibilistic', 'rich'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['acrylic', 'atmospheric', 'coatings', 'developing'] will be ignored
#   warnings.warn(
# Validation Epoch 1:  96%|█████████▋| 27/28 [00:03<00:00,  7.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['autotag', 'generating'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['array', 'coating', 'fabrication', 'gan', 'nanospheres', 'nomarski', 'silica', 'spin'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['diabetic', 'maculopathy', 'retinopathy'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['connotations', 'geodata', 'issues'] will be ignored
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['mood', 'physiological', 'signals'] will be ignored
#   warnings.warn(
# Validation Epoch 1: 100%|██████████| 28/28 [00:04<00:00,  6.99it/s]
# Epoch 1, Average Validation Loss: 0.0788
# Training Epoch 2: 100%|██████████| 223/223 [02:09<00:00,  1.73it/s]
# Epoch 2, Average Training Loss: 0.0584
# Validation Epoch 2: 100%|██████████| 28/28 [00:04<00:00,  7.00it/s]
# Epoch 2, Average Validation Loss: 0.0435
# Training Epoch 3: 100%|██████████| 223/223 [02:09<00:00,  1.73it/s]
# Epoch 3, Average Training Loss: 0.0411
# Validation Epoch 3: 100%|██████████| 28/28 [00:03<00:00,  7.02it/s]
# Epoch 3, Average Validation Loss: 0.0359

# %%
import pandas as pd
import torch
import torch.nn as nn
from transformers import BartTokenizer, BartForConditionalGeneration, AutoTokenizer, AutoModelForSequenceClassification
from keybert import KeyBERT
from sklearn.feature_extraction.text import TfidfVectorizer
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from tqdm import tqdm
import numpy as np
import os
from rouge_score import rouge_scorer
from bert_score import score as bert_score

# Preprocess dataset to extract title keywords
def preprocess_dataset(input_csv, output_csv):
    df = pd.read_csv(input_csv)
    kw_model = KeyBERT()
    
    def extract_keywords(title):
        try:
            keywords = kw_model.extract_keywords(
                title, keyphrase_ngram_range=(1, 7), top_n=10
            )
            return ' '.join([kw[0] for kw in keywords])
        except:
            return ''
    
    df['title_keywords'] = df['title'].apply(extract_keywords)
    df.to_csv(output_csv, index=False)
    return df

# RoBERTa-based keyword prediction function
def predict_keywords(abstract, roberta_model, roberta_tokenizer, keyword_vocab, max_len=512, device='cuda'):
    roberta_model.eval()
    encoding = roberta_tokenizer(
        abstract,
        add_special_tokens=True,
        max_length=max_len,
        return_token_type_ids=False,
        padding='max_length',
        truncation=True,
        return_tensors='pt'
    )
    
    with torch.no_grad():
        outputs = roberta_model(
            input_ids=encoding['input_ids'].to(device),
            attention_mask=encoding['attention_mask'].to(device)
        )
    
    logits = outputs.logits
    predictions = torch.sigmoid(logits).squeeze()
    predicted_keywords = [keyword_vocab[i] for i, prob in enumerate(predictions) if prob > 0.5]
    return predicted_keywords

# Custom Dataset
class ScientificPaperDataset(Dataset):
    def __init__(self, csv_file, bart_tokenizer, roberta_model, roberta_tokenizer, keyword_vocab, max_length=512, device='cuda'):
        self.df = pd.read_csv(csv_file)
        self.bart_tokenizer = bart_tokenizer
        self.roberta_model = roberta_model
        self.roberta_tokenizer = roberta_tokenizer
        self.keyword_vocab = keyword_vocab
        self.max_length = max_length
        self.device = device

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        abstract = str(self.df.iloc[idx]['abstract'])
        title = str(self.df.iloc[idx]['title'])
        title_keywords = str(self.df.iloc[idx]['title_keywords'])

        # Predict abstract keywords using RoBERTa
        abstract_keywords = predict_keywords(abstract, self.roberta_model, self.roberta_tokenizer, self.keyword_vocab, device=self.device)
        abstract_keywords_text = ' '.join(abstract_keywords) if abstract_keywords else ''

        # Input for BART: RoBERTa-predicted keywords + abstract
        input_text = f"Keywords: {abstract_keywords_text} [SEP] Abstract: {abstract}"

        input_encoding = self.bart_tokenizer(
            input_text,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        title_encoding = self.bart_tokenizer(
            title,
            max_length=128,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        return {
            'input_ids': input_encoding['input_ids'].squeeze(),
            'attention_mask': input_encoding['attention_mask'].squeeze(),
            'title_input_ids': title_encoding['input_ids'].squeeze(),
            'title_attention_mask': title_encoding['attention_mask'].squeeze(),
            'title_keywords': title_keywords,
            'abstract_keywords': abstract_keywords_text,
            'title': title
        }

# Multi-task BART Model
class MultiTaskBART(nn.Module):
    def __init__(self, bart_model_name='facebook/bart-base'):
        super(MultiTaskBART, self).__init__()
        self.bart = BartForConditionalGeneration.from_pretrained(bart_model_name)
        self.tokenizer = BartTokenizer.from_pretrained(bart_model_name)
        self.tfidf = TfidfVectorizer(max_features=3000)

    def forward(self, input_ids, attention_mask, title_input_ids, title_keywords, abstract_keywords):
        outputs = self.bart(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=title_input_ids
        )
        title_loss = outputs.loss

        try:
            keyword_vectors = self.tfidf.fit_transform([title_keywords, abstract_keywords]).toarray()
            title_kw_vector = torch.tensor(keyword_vectors[0], dtype=torch.float32)
            abstract_kw_vector = torch.tensor(keyword_vectors[1], dtype=torch.float32)
            cosine_sim = nn.functional.cosine_similarity(title_kw_vector, abstract_kw_vector, dim=0)
            keyword_loss = 1 - cosine_sim
        except:
            keyword_loss = torch.tensor(0.0, device=input_ids.device)

        return title_loss, keyword_loss

# Training and Validation Function
def train_and_validate(model, train_loader, val_loader, device, epochs=3, lr=5e-5, title_loss_weight=1.0, keyword_loss_weight=0.5):
    optimizer = AdamW(model.parameters(), lr=lr)
    
    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for batch in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            title_input_ids = batch['title_input_ids'].to(device)
            title_keywords = batch['title_keywords']
            abstract_keywords = batch['abstract_keywords']

            title_loss, keyword_loss = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                title_input_ids=title_input_ids,
                title_keywords=title_keywords,
                abstract_keywords=abstract_keywords
            )

            loss = title_loss_weight * title_loss + keyword_loss_weight * keyword_loss
            total_train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_train_loss = total_train_loss / len(train_loader)
        print(f"Epoch {epoch + 1}, Average Training Loss: {avg_train_loss:.4f}")

        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f"Validation Epoch {epoch + 1}"):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                title_input_ids = batch['title_input_ids'].to(device)
                title_keywords = batch['title_keywords']
                abstract_keywords = batch['abstract_keywords']

                title_loss, keyword_loss = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    title_input_ids=title_input_ids,
                    title_keywords=title_keywords,
                    abstract_keywords=abstract_keywords
                )

                loss = title_loss_weight * title_loss + keyword_loss_weight * keyword_loss
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        print(f"Epoch {epoch + 1}, Average Validation Loss: {avg_val_loss:.4f}")

# Evaluation Function with ROUGE and BERTScore
def evaluate_model(model, test_loader, device):
    model.eval()
    generated_titles = []
    reference_titles = []
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL', 'rougeLsum'], use_stemmer=True)
    rouge_scores = {'rouge1': [], 'rouge2': [], 'rougeL': [], 'rougeLsum': []}

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            titles = batch['title']

            # Generate titles
            generated_ids = model.bart.generate(
                input_ids=input_ids,
                attention_mask=attention_mask,
                max_length=32,
                num_beams=4,
                length_penalty=2.0,
                early_stopping=True
            )
            generated_title = [model.tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]

            generated_titles.extend(generated_title)
            reference_titles.extend(titles)

            # Compute ROUGE scores
            for gen, ref in zip(generated_title, titles):
                scores = scorer.score(ref, gen)
                for metric in rouge_scores:
                    rouge_scores[metric].append(scores[metric].fmeasure)

    # Compute BERTScore
    try:
        P, R, F1 = bert_score(generated_titles, reference_titles, lang="en", verbose=True)
        bertscore_f1 = F1.mean().item()
    except:
        bertscore_f1 = 0.0

    # Average ROUGE scores
    avg_rouge = {metric: np.mean(scores) for metric, scores in rouge_scores.items()}

    # Print results
    print("\nEvaluation Results:")
    print(f"ROUGE-1: {avg_rouge['rouge1']:.4f}")
    print(f"ROUGE-2: {avg_rouge['rouge2']:.4f}")
    print(f"ROUGE-L: {avg_rouge['rougeL']:.4f}")
    print(f"ROUGE-Lsum: {avg_rouge['rougeLsum']:.4f}")
    print(f"BERTScore F1: {bertscore_f1:.4f}")

    # Save generated titles
    results_df = pd.DataFrame({
        'reference_title': reference_titles,
        'generated_title': generated_titles
    })
    results_df.to_csv('/kaggle/working/generated_titles.csv', index=False)

    return avg_rouge, bertscore_f1

# Main Execution
if __name__ == "__main__":
    # File paths
    train_csv = '/kaggle/input/springerjournal-450tk-0-7cosine/train.csv'
    val_csv = '/kaggle/input/springerjournal-450tk-0-7cosine/val.csv'
    test_csv = '/kaggle/input/springerjournal-450tk-0-7cosine/test.csv'
    processed_train_csv = '/kaggle/working/processed_train.csv'
    processed_val_csv = '/kaggle/working/processed_val.csv'
    processed_test_csv = '/kaggle/working/processed_test.csv'

    # Preprocess datasets
    preprocess_dataset(train_csv, processed_train_csv)
    preprocess_dataset(val_csv, processed_val_csv)
    preprocess_dataset(test_csv, processed_test_csv)

    # Initialize device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load RoBERTa model and tokenizer for keyword prediction
    roberta_model_path = '/kaggle/working/finetuned_roberta_keywords'
    if not os.path.exists(roberta_model_path):
        raise FileNotFoundError(f"RoBERTa model directory {roberta_model_path} does not exist. Please run the fine-tuning script first.")
    roberta_model = AutoModelForSequenceClassification.from_pretrained(roberta_model_path).to(device)
    roberta_tokenizer = AutoTokenizer.from_pretrained(roberta_model_path)

    # Load keyword vocabulary
    keyword_vocab_path = '/kaggle/working/keyword_vocab.txt'
    if not os.path.exists(keyword_vocab_path):
        raise FileNotFoundError(f"Keyword vocabulary file {keyword_vocab_path} does not exist. Please run the fine-tuning script first.")
    with open(keyword_vocab_path, 'r') as f:
        keyword_vocab = [line.strip() for line in f]

    # Initialize BART tokenizer and datasets
    bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')
    train_dataset = ScientificPaperDataset(processed_train_csv, bart_tokenizer, roberta_model, roberta_tokenizer, keyword_vocab, device=device)
    val_dataset = ScientificPaperDataset(processed_val_csv, bart_tokenizer, roberta_model, roberta_tokenizer, keyword_vocab, device=device)
    test_dataset = ScientificPaperDataset(processed_test_csv, bart_tokenizer, roberta_model, roberta_tokenizer, keyword_vocab, device=device)

    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

    # Initialize BART model
    bart_model = MultiTaskBART().to(device)

    # Train and validate
    train_and_validate(bart_model, train_loader, val_loader, device, epochs=3, lr=5e-5, 
                       title_loss_weight=1.0, keyword_loss_weight=0.5)

    # Evaluate on test set
    rouge_results, bertscore_result = evaluate_model(bart_model, test_loader, device)

    # Save the model
    bart_model.bart.save_pretrained('/kaggle/working/multi_task_bart_model')
    bart_tokenizer.save_pretrained('/kaggle/working/multi_task_bart_model')
# Out:
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# Training Epoch 1: 100%|██████████| 446/446 [03:42<00:00,  2.01it/s]
# Epoch 1, Average Training Loss: 0.8695
# Validation Epoch 1: 100%|██████████| 56/56 [00:13<00:00,  4.12it/s]
# Epoch 1, Average Validation Loss: 0.2274
# Training Epoch 2: 100%|██████████| 446/446 [03:41<00:00,  2.01it/s]
# Epoch 2, Average Training Loss: 0.2016
# Validation Epoch 2: 100%|██████████| 56/56 [00:13<00:00,  4.15it/s]
# Epoch 2, Average Validation Loss: 0.2290
# Training Epoch 3: 100%|██████████| 446/446 [03:41<00:00,  2.02it/s]
# Epoch 3, Average Training Loss: 0.1555
# Validation Epoch 3: 100%|██████████| 56/56 [00:13<00:00,  4.13it/s]
# Epoch 3, Average Validation Loss: 0.2331
# Evaluating: 100%|██████████| 56/56 [00:24<00:00,  2.30it/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 1.10 seconds, 202.20 sentences/sec
#
# Evaluation Results:
# ROUGE-1: 0.6498
# ROUGE-2: 0.4490
# ROUGE-L: 0.5835
# ROUGE-Lsum: 0.5835
# BERTScore F1: 0.9236
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:3339: UserWarning: Moving the following attributes in the config to the generation config: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
